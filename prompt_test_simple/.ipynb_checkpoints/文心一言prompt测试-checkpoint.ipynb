# %%
import pandas as pd
import json

# load CMMLU test data
market_data_path = "CMMLU/data/test/marketing.csv"
econ_data_path = "CMMLU/data/test/economics.csv"
ch_his_path = "CMMLU/data/test/chinese_history.csv"
# Read the CSV file
market_data = pd.read_csv(market_data_path)
econ_data = pd.read_csv(econ_data_path)
ch_his_data = pd.read_csv(ch_his_path)

test_data = econ_data
columns_as_lists = {col: econ_data[col].tolist() for col in econ_data.columns}

# Display the first few rows of the dataframe
test_data.head()
# Out:
#    Unnamed: 0                                    Question  \
# 0           0          一种产品价格的大幅度减少，导致另一种产品销售量的提高，这两种产品属于
# 1           1                                      风险补偿率是
# 2           2                   如果其他因素保持不变，下列哪种情况一定会使需求减少
# 3           3  一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为
# 4           4                              垄断竞争企业的竞争方式不包括
#
#                           A                B                C  \
# 0                       独立品              互补品              替代品
# 1  加在无风险的贴现率上，以便在决策中把风险考虑进去      只供风险决策者决策时用            B和C都对
# 2           收入减少，同时互补品的价格下降  收入增加，同时替代品的价格上涨  收入减少，同时互补品的价格上涨
# 3                      垄断竞争             完全竞争               寡头
# 4                   产品差异化竞争             价格竞争             专利竞争
#
#                        D Answer
# 0                    低档品      B
# 1  要从无风险贴现率减去，以便在决策中考虑风险      A
# 2        收入增加，同时替代品的价格下降      C
# 3                     垄断      A
# 4                广告和促销竞争      C

# %%
# forumulate questions
initial_instruction = """
这个题目是单选题

#回答格式#
答案是【你的答案】来标注你的答案。

#答案选项#
A

B

C

D

#样例#
答案是A
"""

def initial_prompt(num):
    question = columns_as_lists['Question'][num]
    op_A = columns_as_lists['A'][num]
    op_B = columns_as_lists['B'][num]
    op_C = columns_as_lists['C'][num]
    op_D = columns_as_lists['D'][num]
    complete_prompt = f"{initial_instruction} \n {question}\n A {op_A} \n B {op_B} \n C {op_C} \n D {op_D}"
    question_only = f"{question}"
    options = f"A {op_A} \n B {op_B} \n C {op_C} \n D {op_D}"
    return complete_prompt, question_only, options

# %%
# remove the answer
df_test = test_data.iloc[:, :-1]

second_column_name = df_test.columns[0]
df_test = df_test.drop(columns=[second_column_name])

# %%
#format the initial prompt
for row in df_test.iterrows():
    print(row[1])

# %%
from langchain_wenxin.llms import Wenxin 
from langchain.schema.messages import HumanMessage

WENXIN_APP_Key = "vtPwTlnPvgIdb4DRSuyNDuIN"
WENXIN_APP_SECRET = "Sp8CCvNsQgUsRKlJozQwWVClRliZ2S8m"

llm = Wenxin(
    temperature=0.3,
    model="ernie-bot-turbo",
    baidu_api_key = WENXIN_APP_Key,
    baidu_secret_key = WENXIN_APP_SECRET,
    verbose=True,
)
# Out:
# /tmp/ipykernel_1809/347693217.py:7: DeprecationWarning: This Wenxin LLM is deprecated. Please use `from langchain.chat_models import ChatWenxin` instead
#   llm = Wenxin(

# %%
import re
# check if there is a pattern exist in the input string
# return the found pattern string else return None
def check_pattern(string, pattern):
    # Define the pattern
    pattern = pattern
    # Search for the pattern in the string
    match = re.search(pattern, string)
    # Return True if the pattern is found, otherwise False
    return match.group(0) if match else None

# %%
answers = columns_as_lists['Answer']
# this function test the if the agent answer the question correctly
def test(response, num):
    true_answer = answers[num]
    print(f"文言一心的回答是：{response}")
    print(f"Answer is {true_answer}")
    
    answer_part = check_pattern(response, r'答案.*[ABCD]') #find the string that contains only the answer
    
    if answer_part != None:
        letter = answer_part[-1]
        if letter==true_answer:
            print(f"question {num} is correct!")
            return 1
    else:    
        print("Error: didn't find answer for this question")
        return 0
    return 0

# %%
#Prompt 评分专家
prompt_analyst="""
你是一个优秀的Prompt专家，对于一个Prompt，你会按照这5个维度来打分。

#评分标准#

明确性（Clarity）：30分。如果Prompt不清晰或容易引起混淆，那么AI的回答可能会偏离预期，因此明确性是最基本的要求之一。

实用性（Practicality）：25分。Prompt的目的是要为用户提供实用的信息和解决问题的策略，所以实用性也是相当重要的。

创新性（Innovation）：15分。虽然这不是必需的，但创新性能够让Prompt产生独特的、富有洞察力的回答，有时甚至可能开辟全新的应用领域。

结果稳定性（Consistency of Output）：15分。为了确保用户可以依赖AI的回答，结果的一致性和预见性是非常重要的。

通用性（Universality）：15分。虽然有些Prompt可能特定于某一场景，但如果一个Prompt可以在多个场景下产生有效的结果，那么它的价值就更大。

#任务#
请给我的这个prompt打分，加总，并说明理由，最后做一个优化修改。

#工作流程#
1."分析你的问题（Prompt）",
2."基于评分标准，对提供的prompt进行各项评分",
3."对每一个评分项进行解释",
4."基于你的问题进行写出工作流程，回复不低于5个步骤",
5. Initialization，内容一定要是基于我提问的问题
5."生成回复，确保回复符合预期"
6.“提供一个优化修改之后的prompt”

#输出格式#
输出一个JSON，4个字段："提示词"，"优化后的提示词"，"总评分"，"工作流程"
{
    "提示词": ##【填入你要评估的提示词】##,
    "优化后的提示词"：##【在这里填入你优化后产生的提示词】##
    "总评分": #【你对这个prompt的总评分】#,
}

## Initialization：
    接下来我会给出我的问题(Prompt)，请根据我的Prompt
    1.基于[CRISPE提示框架]，请一步一步进行输出，直到最终输出[优化Promot]；
    2.输出完毕之后，请咨询我是否有需要改进的意见，如果有建议，请结合建议重新基于[CRISPE提示框架]输出。
    要求：请避免讨论[CRISPE提示框架]里的内容；
"""

# %%
import template_new
from template_new import co_star_agent_prompt, CRISPE_prompt
prompt_optimize_prompt = """
# # Role:Prompt工程师
1. Don't break character under any circumstance.
2. Don't talk nonsense and make up facts.

## Profile:
- Version:1.4
- Language:中文
- Description:你是一名优秀的Prompt工程师，你熟悉[CRISPE提示框架]，并擅长将常规的Prompt转化为符合[CRISPE提示框架]的优秀Prompt，并输出符合预期的回复。

## Constrains:
- Role: 基于我的Prompt，思考最适合扮演的1个或多个角色，该角色是这个领域最资深的专家，也最适合解决我的问题。
- Profile: 基于我的Prompt，思考我为什么会提出这个问题，陈述我提出这个问题的原因、背景、上下文。
- Goals: 基于我的Prompt，思考我需要提给LLM的任务清单，完成这些任务，便可以解决我的问题。
- Skill：基于我的Prompt，思考我需要提给LLM的任务清单，完成这些任务，便可以解决我的问题。
- OutputFormat: 基于我的Prompt，基于我OutputFormat实例进行输出。
- Workflow: 基于我的Prompt，要求提供几个不同的例子，更好的进行解释。
- Don't break character under any circumstance.
- Don't talk nonsense and make up facts.
- 如果你认为Prompt足够优秀无需修改，请直接使用OutputFormat实例进行输出

## OutputFormat:
   
    ## OutputFormat:
    #输出格式#
    =====
    不要修改我提供的选项
    =====
    输出一个JSON，3个字段："提示词"，"优化后的提示词"，"选项"
    {
        "提示词": ##【填入你要优化的提示词】##,
        "优化后的提示词":##【在这里填入你优化后产生的提示词】##,
        "选项":["A.#【选项A的内容】#", "B.#【选项B的内容】#", "C.#【选项C的内容】#", "D.#【选项D的内容】#"]
    }

    #输出示例#
    {
        "提示词": "你要优化的提示词是：下列注重卖方需要的市场营销管理哲学是",
        "优化后的提示词":"请选择一个注重卖方需要的市场营销管理哲学？您可以从市场营销观念、社会市场营销观念、客户观念和生产观念中挑选一个最符合您需求的选项。"
        "选项": ["A. 市场营销观念", "B. 社会市场营销观念", "C. 客户观念", "D. 生产观念"]
    }

## Skill:
1. 熟悉[CRISPE提示框架]。
2. 能够将常规的Prompt转化为符合[CRISPE提示框架]的优秀Prompt。

## Workflow:
1. 分析我的问题(Prompt)。
2. 根据[CRISPE提示框架]的要求，确定最适合扮演的角色。
3. 根据我的问题(Prompt)的原因、背景和上下文，构建一个符合[CRISPE提示框架]的优秀Prompt。
4. 解释拓展prompt中提及的关键词、专业术语
4. Workflow，基于我的问题进行写出Workflow，回复不低于5个步骤，提供解题逻辑和步骤
5. Initialization，内容一定要是基于我提问的问题
6. 生成回复，确保回复符合预期。
    

## Initialization：
    接下来我会给出我的问题(Prompt)，请根据我的Prompt
    1.基于[CRISPE提示框架]，请一步一步进行输出，直到最终输出[优化Promot]；
    2.输出完毕之后，请咨询我是否有需要改进的意见，如果有建议，请结合建议重新基于[CRISPE提示框架]输出。
    要求：请避免讨论[CRISPE提示框架]里的内容；
    不需要重复内容，如果你准备好了，告诉我。"""

# %%
content_extract_prompt = """
# # Role:内容提取工程师
1. Don't break character under any circumstance.
2. Don't talk nonsense and make up facts.

## Profile:
- Version:1.4
- Language:中文
- Description:你是一名优秀的内容提取工程师，你熟悉[CRISPE提示框架]，擅长读取输入的内容并提取有效的信息，并输出符合预期的回复。

## Constrains:
- Role: 基于我输入的内容，提取优化之后的prompt
- Skill：理解我输入的内容，精准定位我提供的内容中优化之后的prompt是什么
- OutputFormat: 基于我的Prompt，基于我OutputFormat实例进行输出。

## OutputFormat:
   #输出格式#
    =====
    不要修改我提供的选项
    =====
    输出一个JSON，2个字段："提示词"，"优化后的提示词"
    {
        "提示词": ##【填入你要优化的提示词】##,
        "优化后的提示词":##【在这里填入你优化后产生的提示词】##,
    }

    #输出示例#
    {
        "提示词": "你要优化的提示词是：下列注重卖方需要的市场营销管理哲学是",
        "优化后的提示词":"请选择一个注重卖方需要的市场营销管理哲学？您可以从市场营销观念、社会市场营销观念、客户观念和生产观念中挑选一个最符合您需求的选项。"
    }
    
## Skill:
1. 熟悉[CRISPE提示框架]。
2. 提取输入内容的重要信息，并跟据<OutputFormat>输出内容

## Workflow:
1. 分析我的输入内容
4. Workflow，基于我的问题进行写出Workflow，回复不低于5个步骤
5. Initialization，内容一定要是基于我输入的内容
6. 生成优化之后prompt，确保回复符合预期，不要回答prompt中的问题，请使用[OutputFormat]。

## Initialization：
    接下来我会给出我优化的prompt，请根据我输入的内容：
    1.基于[CRISPE提示框架]，请一步一步进行输出，直到最终输出[优化Promot]；
    2.输出完毕之后，请咨询我是否有需要改进的意见，如果有建议，请结合建议重新基于[CRISPE提示框架]输出。
    要求：请避免讨论[CRISPE提示框架]里的内容；
    不需要重复内容，如果你准备好了，告诉我。
    
=====
    """

# %%
def prompt_extractor(input):
    optimized_prompt = llm(content_extract_prompt + "我输入的内容："+ input)
    return optimized_prompt

# %%
def prompt_optimization(initial_prompt, options):
    if len(initial_prompt) <= 1:
        raise ValueError("Invalid prompt input")
    optimized_prompt = prompt_optimize_prompt
    input_prompt = f"""{optimized_prompt}
    
#你要优化的提示词#
{initial_prompt} 
    
{options} 
""" 
    new_prompt = llm(input_prompt)
    return new_prompt

# %%
s = prompt_optimization("写一篇关于特朗普的报告", " ")
print(s)
# Out:
# ## 输出格式
#
# {
# "提示词": "写一篇关于特朗普的报告",
# "优化后的提示词": "请选择一个关于特朗普的报告主题，并给出符合要求的报告内容。",
# "选项": ["A. 特朗普的政治观点和政策", "B. 特朗普的商业成功和失败", "C. 特朗普的个人经历和成长", "D. 特朗普的社交媒体使用习惯"]}
#
# ## 工作流程
#
# 1. 首先，我们需要了解特朗普的主要政治观点和政策，分析其对美国政治、经济和社会的影响。
# 2. 其次，我们可以探讨特朗普的商业成功和失败，分析其商业策略和领导能力。
# 3. 然后，我们可以从特朗普的个人经历和成长角度出发，分析他的性格、价值观和决策风格。
# 4. 最后，我们可以关注特朗普的社交媒体使用习惯，分析其在社交媒体上的影响力。
#
# ## 初始化和回复
#
# 基于您给出的提示词，我将根据工作流程逐步生成回复。
#
# ### 初始化
#
# 您好，特朗普是一位备受关注的政治人物，他的政治观点和政策对美国社会产生了深远的影响。我将根据您给出的提示词，为您生成一份关于特朗普的政治观点和政策的报告。
#
# ### 回复
#
# 报告内容如下：
#
# 特朗普在政治领域取得了显著的成就，他主张自由市场经济，推动了一系列有利于企业家的税收和监管政策。同时，他主张减少政府干预，加强了美国在国际事务中的地位。这些政策在短期内促进了经济增长，但也引发了一些社会问题，如种族歧视和贫富差距扩大等。
#
# 希望这份报告符合您的要求。如果您有任何其他问题或需要改进的建议，请随时告诉我。

# %%
p = prompt_optimization("这是一个选择题，一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为什么",
"""
A 垄断竞争
B 完全竞争
C 寡头
D 垄断""")
print(p)
# Out:
# ## OutputFormat:
#
# ### Output一个JSON
#
# ```json
# {
#     "提示词": "你要优化的提示词是：一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为什么",
#     "优化后的提示词": "请选择一个市场结构？市场结构可以分为完全竞争、垄断竞争、寡头和垄断四种类型，您可以从这四种类型中选择一个最符合您当前行业情况的选项。",
#     "选项": ["A. 完全竞争", "B. 垄断竞争", "C. 寡头", "D. 垄断"]
# }
# ```
#
# ### Output示例
#
# ```json
# {
#     "提示词": "你要优化的提示词是：一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为什么",
#     "优化后的提示词": "这是一个选择题，市场结构可以分为完全竞争、垄断竞争、寡头和垄断四种类型，您可以从这四种类型中选择一个最符合您当前行业情况的选项。",
#     "选项": ["A. 完全竞争", "B. 垄断竞争", "C. 寡头"]
# }
# ```
#
# ## Skill:
#
# * 熟悉问题的背景和上下文。
# * 能够根据问题类型，选择合适的答案选项。
#
# ## Workflow:
#
# 1. **分析问题**：首先，我分析了您的问题，它涉及到市场结构的分类。
# 2. **确定角色**：基于我的Prompt，我思考最适合扮演的1个或多个角色，即市场结构分类领域的专家。这个角色需要能够根据不同的市场情况，选择合适的市场结构类型。
# 3. **构建Prompt**：基于上述角色和问题背景，我构建了一个符合[CRISPE提示框架]的优秀Prompt。这个Prompt首先解释了市场结构的分类，然后给出了四个可能的选项供用户选择。
# 4. **输出优化后的Prompt**：根据上述分析，我优化了Prompt，使其更符合问题的要求。同时，我也考虑了用户可能会提出的问题，并给出了相应的答案选项。
# 5. **反馈与改进**：如果您对输出结果满意，您可以告诉我。如果您有任何改进的建议，我会根据您的反馈重新进行优化。
#
# ## Initialization:
#
# 根据您给出的初始化信息，我将基于您的问题进行初始化。接下来我会按照[CRISPE提示框架]的要求进行输出，直到最终输出优化后的Prompt。
#
# ### 步骤一：基于问题背景和上下文进行输出
#
# 根据您提供的问题背景和上下文，我为您输出以下内容：
#
# * 行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为**垄断竞争**。这是最常见的市场结构之一。
# * 您可以选择以下答案中的一个来回答这个问题：A. 完全竞争、B. 垄断竞争、C. 寡头、D. 垄断。这个答案将帮助您更好地理解市场结构的概念。
#
# ### 步骤二：询问是否需要改进意见
#
# 如果您对上述输出结果满意，您可以告诉我。如果您认为还有需要改进的地方，请提供您的建议，我将根据您的反馈重新进行优化。

# %%
def grammer_checking_agent(json_input):
    prompt = """
    # # Role:JSON工程师
    1. Don't break character under any circumstance.
    2. Don't talk nonsense and make up facts.
    
    ## Skill:
    1. 熟悉[JSON框架]。
    2. 能够识别我提供的JSON里的问题。
    3. 能够修改JSON中的bug，使我的JSON输入完整而且没有bug
    
    ## Constrains:
    1. 不要增加输入的JSON的内容
    2. 不要增加输入的JSON的内容
    3. 与<OutputFormat>结构保持一致
    
    ## WorkFlow
    1. 识别输入JSON中的问题
    2. 修复输入JSON中的问题
    3. 根据OutputFormat输出修复完整的JSON
    
    ## OutputFormat
    输出一个JSON，5个字段："提示词"，"优化后的提示词"，"选项"
    {
        "提示词": ##【填入你要优化的提示词】##,
        "优化后的提示词":##【在这里填入你优化后产生的提示词】##,
        "选项":["A.#【选项A的内容】#", "B.#【选项B的内容】#", "C.#【选项C的内容】#", "D.#【选项D的内容】#"]
    }

    #输出示例#
    {
        "提示词": "你要优化的提示词是：下列注重卖方需要的市场营销管理哲学是",
        "优化后的提示词":"请选择一个注重卖方需要的市场营销管理哲学？您可以从市场营销观念、社会市场营销观念、客户观念和生产观念中挑选一个最符合您需求的选项。"
        "选项": ["A. 市场营销观念", "B. 社会市场营销观念", "C. 客户观念", "D. 生产观念"]
    }
    
    """
    response = llm(prompt + "你要修改的JSON是： " + json_input)
    
    return response

# %%
import regex
#处理优化后的提示词
def prompt_preprocess(prompt):
    found_pattern = regex.compile(r'\{(?:[^{}]|(?R))*\}')
    json_prompt = found_pattern.findall(prompt)
    if len(json_prompt) < 1:
        return prompt
    print(json_prompt[0])
    try:
        dict_prompt = json.loads(json_prompt[0]) # a dictionary contain the optimized prompt
        if "优化后的提示词" in dict_prompt:
            return dict_prompt["优化后的提示词"]
    except ValueError as e:
        print(f"Invalid JASON {e}")
        correct_json_str = grammer_checking_agent(json_prompt[0]) # use LLM to correct the grammer of JSON
        correct_json = found_pattern.findall(correct_json_str)
        dict_prompt = json.loads(json_prompt[0])
        if "优化后的提示词" in dict_prompt:
            return dict_prompt["优化后的提示词"]
        return dict_prompt

# %%
def prompt_eval_agent(prompt):
    input_prompt = prompt_analyst
    response = llm(input_prompt + "/n 你要评分的prompt：" + prompt)
    return response

# %%
print(prompt_eval_agent(p))
# Out:
# 根据给定的评分标准，对这个Prompt进行评分：
#
# 明确性：这个Prompt清晰地表达了一个问题，没有引起混淆。分数：30分
# 实用性：这个Prompt提供了实用的信息和解决问题的策略，符合实用性评分标准。分数：25分
# 创新性：这个Prompt没有涉及创新性的内容，因此创新性得分是0分。
# 结果稳定性：这个Prompt似乎在描述一个事实或问题，因此结果稳定性得分也是30分。
# 通用性：这个Prompt似乎是一个选择题，可以在多个场景下使用，因此通用性得分是30分。
#
# 总评分：125分
#
# 优化后的Prompt：
#
# 选择题：一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为“垄断竞争”。你是否还有其他问题？
#
# 优化理由：更明确地表达了问题，使用了更精确的语言，并且增加了确认是否还有其他问题的步骤，以增加用户体验。
#
# 工作流程：
#
# 1. **分析问题**：一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构是什么？
# 2. **给出答案**：根据所提供的信息，市场结构被称为“垄断竞争”。
# 3. **确认理解**：询问是否还有其他问题，以确保用户完全理解答案。
# 4. **接收新问题**：如果用户有新的问题，按照工作流程进行下一步。如果没有新问题，结束工作流程。
#
# JSON输出：
#
# ```json
# {
#     "提示词": "基于你提供的信息，一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为“垄断竞争”。你是否还有其他问题？",
#     "优化后的提示词": "选择题: 一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为‘垄断竞争’。你是否还有其他问题?",
#     "总评分": "125分",
#     "工作流程": "分析问题 -> 给出答案 -> 确认理解 -> 接收新问题"
# }
# ```

# %%
#original without optimization prompt
total_q = 30
count = 0
for i in range(total_q):
    initial_p, question_only, options= initial_prompt(i)
    response = llm(initial_p)
    count += test(response, i)

count / total_q
# Out:
# 文言一心的回答是：答案是 C 替代品。
#
# 根据题目描述，一种产品价格大幅度减少，导致另一种产品销售量的提高，说明这两种产品可以相互替代，属于替代品关系。独立品、互补品和低档品都不会出现这种价格变动引起销售量变动的情况。因此，答案为C。
# Answer is B
# 文言一心的回答是：答案是A。风险补偿率是加在无风险的贴现率上，以便在决策中把风险考虑进去。
# Answer is A
# question 1 is correct!
# 文言一心的回答是：答案是A。
#
# 如果其他因素保持不变，当收入减少同时互补品的价格下降时，一定会使需求减少。因为当收入减少时，消费者的购买能力下降，对于价格较高的互补品的需求也会随之减少；而当互补品的价格下降时，消费者可能会认为该商品更加便宜，从而增加对该商品的需求。因此，这两个因素共同作用，一定会导致需求减少。
# Answer is C
# 文言一心的回答是：答案是A。垄断竞争。
#
# 解释：题目中提到一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这表明市场存在竞争，但每个企业又有一定的垄断地位，因此市场结构被称为垄断竞争。完全竞争、寡头和垄断都是不同的市场结构，但与题目描述的情况不符。
# Answer is A
# question 3 is correct!
# 文言一心的回答是：答案是C。垄断竞争企业的竞争方式不包括专利竞争。垄断竞争市场是一种不完全竞争市场，企业在市场中具有垄断地位，但仍然存在其他企业之间的竞争。在垄断竞争市场中，企业之间的竞争方式主要包括产品差异化竞争、价格竞争、广告和促销竞争等。专利竞争不属于这些竞争方式之一。
# Answer is C
# question 4 is correct!
# 文言一心的回答是：答案是D.凯恩斯。提出消费倾向递减心理规律的经济学家是凯恩斯。
# Answer is D
# question 5 is correct!
# 文言一心的回答是：答案是A。
#
# 需求的收入弹性是指收入对需求变化的反应程度。也就是说，当收入变化时，需求也会相应地发生变化，这种变化的大小可以用弹性这个指标来衡量。
# Answer is B
# 文言一心的回答是：答案是B。根据题目描述，如果投资方案未来全部净现金效益量的现值大于期初投资，企业应该接受该方案。因此，选项B“接受该方案”是正确的答案。选项A“还需要再研究”可能意味着企业还需要更多的信息或研究来确定是否应该接受该方案，选项C“无法确定”则过于模糊，而选项D“拒绝该方案”则与题目描述相悖。
# Answer is B
# 文言一心的回答是：答案是A。在完全竞争市场上，一个企业的需求曲线是与横轴平行的线。在完全竞争市场中，所有企业都是价格的接受者，他们的销售量由市场决定。这种情况下，企业的需求曲线就是市场的需求曲线，是一条与横轴平行的线，表示市场总需求量与价格之间的关系。
# Answer is A
# question 8 is correct!
# 文言一心的回答是：答案是B
# 最常用的三种投资方案评价方法是返本期法、净现值法、内部回报率法。
# Answer is B
# question 9 is correct!
# 文言一心的回答是：答案是【C 两个方案的现值相等】。
#
# 解释：根据题目描述，甲方案头三年的净现金效益量分别为l00元、100元和100元，乙方案头三年的现金效益量分别为80元、100元和120元。由于两个方案的头三年现金效益量相等，所以它们的现值也相等。不需要进行贴现计算来确定哪个方案现值大。
# Answer is D
# 文言一心的回答是：答案是B。
#
# 市场失灵是指市场无法有效运作，导致资源分配不均、收入不平等和市场控制等问题。在题目中，选项A和C属于市场失灵的表现之一，而选项D属于自然垄断现象，因此选项B“以上全是”是正确答案。
# Answer is B
# question 11 is correct!
# 文言一心的回答是：答案是D。当长期均衡时，完全竞争企业总是经济利润为零。完全竞争市场中的企业无法控制价格，只能接受市场价格，因此无法获得经济利润。当企业接受市场价格并生产时，它能够获得正常利润，但这并不意味着它总是经济利润为零。因此，答案为D，经济利润为零。
# Answer is D
# question 12 is correct!
# 文言一心的回答是：答案是A。
#
# 解释：在有风险条件下的决策，决策的条件是决策的可能结果有多个，但不知道每种结果发生的概率。在这种情况下，决策者需要根据自己的经验和知识来评估各种结果的可能性，并做出最佳决策。因此，选项A描述了这种情况，即决策者不知道每种结果发生的概率。选项B、C和D都与风险条件下的决策无关，因此不是正确答案。
# Answer is B
# 文言一心的回答是：答案是A。
#
# 用于衡量一个国家金融发展水平的指标是净金融资产。净金融资产是指一个国家或地区的金融资产总量减去负债总量后的净额，包括股票、债券、基金、保险等金融资产，可以反映一个国家金融市场的规模、结构和活跃程度。国民生产总值、金融比率、流动性金融资产虽然也是重要的经济指标，但它们并不能完全反映一个国家金融发展水平的全貌。因此，净金融资产是衡量一个国家金融发展水平的重要指标之一。
# Answer is C
# 文言一心的回答是：答案选项：
#
# A. 政府削减财政支出
#
# B. 中央银行在公开市场上出售政府债券
#
# C. 控制集团购买力
#
# D. 政府确定工资—物价指导线
#
# 答案是B。
#
# 在治理通货膨胀的宏观经济政策中，出售政府债券属于紧缩性货币政策，因为它减少了货币供应量，从而抑制了通货膨胀。而其他选项中，政府削减财政支出、控制集团购买力和政府确定工资—物价指导线都是属于财政政策，它们对货币供应的影响较小，因此不属于紧缩性货币政策。
# Answer is B
# question 15 is correct!
# 文言一心的回答是：答案是C。实施“次级进口替代”战略的基础是先进的科学技术。这是因为“次级进口替代”战略旨在通过进口替代工业的发展，逐步实现经济的进口替代，最终实现经济的自由化。而进口替代工业的发展需要依靠先进的科学技术，包括生产技术、管理技术、研发技术等，以提高生产效率和产品质量，从而获得市场竞争力。自然资源、劳动力、发达的金融市场等因素虽然也是重要的，但不是实施“次级进口替代”战略的基础。
# Answer is A
# 文言一心的回答是：答案：D
#
# 解释：
#
# 假定名义货币供给量不变，价格总水平上升，即实际货币量不变，但货币的价值下降，LM曲线向左上方移动。所以，答案D是正确的。
# Answer is C
# 文言一心的回答是：答案是C。
#
# 解释：
#
# 恩格尔系数是指食品支出占消费总支出的比重。因此，选项C是正确的，而选项A和B都是错误的，因为恩格尔定律在我国是适用的，并且随收入水平提高，恩格尔系数有逐渐下降的趋势。选项D也是错误的，因为恩格尔系数并不总是随收入增加而下降的，它还受到其他因素的影响，如消费习惯、物价水平等。
# Answer is C
# question 18 is correct!
# 文言一心的回答是：答案是A。一种商品价格下降对其互补品最直接的影响是互补品的需求曲线向右移动。当一种商品价格下降时，消费者可能会增加对该商品的需求，从而也会增加对互补商品的需求量，因此互补品的需求曲线会向右移动。
# Answer is A
# question 19 is correct!
# 文言一心的回答是：答案是A。
#
# 属于二级价格歧视的是私人诊所根据不同的人收取不同的价格。这是因为私人诊所可以根据患者的需求、病情、经济状况等因素，制定不同的价格，从而实现更精细的价格控制和利润最大化。其他选项中，去公园老人与小孩的门票低、到超市同时买两块香皂比单独买一个香皂单价低、坐火车，学生半价买火车票，虽然也存在价格差异，但它们不属于二级价格歧视的范畴。
# Answer is C
# 文言一心的回答是：答案是C。有限责任公司签发给股东的出资证明书是一种有价证券。有价证券是证明持有人或该证券所代表的权利的凭证，出资证明书是股东在公司出资的证明，具有相应的财产价值，因此属于有价证券的范畴。
# Answer is B
# 文言一心的回答是：答案是A。
#
# 在完全竞争市场上，单个厂商的生产要素需求曲线向右下方倾斜的原因是要素的边际产量递减。这是因为随着厂商增加要素投入量的增加，每单位要素的贡献会逐渐减少，导致总产量呈现下降趋势。因此，厂商会逐渐减少要素投入量，以保持或提高生产效率。
# Answer is A
# question 22 is correct!
# 文言一心的回答是：答案是A。供给的变动是指在本身的价格不变的条件下，其他因素变动所引起的供给的变动。这意味着在其他因素（如偏好、技术或产量）不变的情况下，价格变动将导致供给的相应变动。
# Answer is A
# question 23 is correct!
# 文言一心的回答是：答案是C。这个题目是单选题，答案选项是C，发行对象事先指定，在小范围内发行的债券是私募债券。
# Answer is C
# question 24 is correct!
# 文言一心的回答是：答案是D。长期生产函数的概念是生产函数中所有投入要素的投入量都是可变的。这意味着在长期生产中，所有投入要素的数量都可以根据生产者的需求进行调整，以实现更高的生产效率和产出。
# Answer is D
# question 25 is correct!
# 文言一心的回答是：答案是C。边际效用递减规律表明，随着消费者对某种商品消费量的增加，该商品的效用增量趋于递减。
# Answer is C
# question 26 is correct!
# 文言一心的回答是：答案是B。
#
# 住房投资依赖于以上全部因素，因为住房投资通常需要考虑到多种因素，包括实际利率、成年人口的规模和住房的相对价格等。这些因素都会对住房投资产生影响。
# Answer is B
# question 27 is correct!
# 文言一心的回答是：答案是B。在完全垄断市场上，对于任何产量，厂商的平均收益总等于边际收益。这是因为完全垄断市场的价格决定于边际成本和需求曲线的关系，而边际收益是总收益对产量的导数，因此它等于平均收益也就不奇怪了。市场价格通常低于边际成本，以刺激生产者增加产出，从而增加社会的总福利。
# Answer is A
# 文言一心的回答是：答案是C。沉没成本是不受决策影响的非相关成本，是指在过去的决策中已经投入的成本，无法改变，因此选项C是正确的答案。社会成本是用于描述由社会或团体共同承担的成本，与本题无关。增量成本是与不采取某项行动时相比，采取行动所增加的成本。机会成本是指为了得到某种东西而所要放弃另一些东西的最大价值。这些选项中，只有沉没成本与不受决策影响的非相关成本的概念相符。
# Answer is C
# question 29 is correct!
# 0.6

# %%
count = 0
total_q = 30 #data.shape[0]
cot_prompt = """
######
请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。"""

for i in range(total_q):
    initial_p, question_only, options= initial_prompt(i)
    optimized_prompt = prompt_optimization(question_only, options)
    prompt = f"""{initial_instruction} 
======
{prompt_preprocess(optimized_prompt)} 
======
{options}  
{cot_prompt}""" # generate new prompt
    print(f"new prompt is {prompt}")
    response = llm(prompt+cot_prompt)# ask agent respond to the question
    count += test(response, i)

count / total_q
# Out:
# {
#     "提示词": "一种产品价格的大幅度减少，导致另一种产品销售量的提高，这两种产品属于",
#     "优化后的提示词": "请选择一种产品价格的大幅度减少，导致另一种产品销售量的提高，这两种产品属于的经济学概念。您可以从替代品、独立品、互补品、低档品中挑选一个最符合您需求的选项。",
#     "选项": ["A. 独立品", "B. 互补品", "C. 替代品", "D. 低档品"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一种产品价格的大幅度减少，导致另一种产品销售量的提高，这两种产品属于的经济学概念。您可以从替代品、独立品、互补品、低档品中挑选一个最符合您需求的选项。
# ======
# A 独立品
#  B 互补品
#  C 替代品
#  D 低档品
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是C：替代品。
#
# 替代品是指两种产品之间存在某种功能上的相似性，可以相互替代。当一种产品价格大幅度减少时，消费者可能会选择另一种具有相同或相似功能的产品来满足他们的需求。这种情况下，替代品的销售量会提高，因为消费者不再需要花费更多的钱来获得相同或相似功能的产品。因此，在这种情况下，这两种产品属于经济学概念中的替代品。
# Answer is B
# {
#     "提示词": "风险补偿率是",
#     "优化后的提示词": "风险补偿率是在决策中考虑到风险时所需要的一个附加的补偿率，通常是在无风险的贴现率上加上的。",
#     "选项": ["A. 加在无风险的贴现率上，以便在决策中把风险考虑进去", "D. 要从无风险贴现率减去，以便在决策中考虑风险"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 风险补偿率是在决策中考虑到风险时所需要的一个附加的补偿率，通常是在无风险的贴现率上加上的。
# ======
# A 加在无风险的贴现率上，以便在决策中把风险考虑进去
#  B 只供风险决策者决策时用
#  C B和C都对
#  D 要从无风险贴现率减去，以便在决策中考虑风险
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是A。
#
# 风险补偿率是在决策中考虑到风险时所需要的一个附加的补偿率，通常是在无风险的贴现率上加上的。这意味着风险补偿率是为了在决策中考虑到风险，通常是在无风险的贴现率上加上一个额外的补偿率。所以，选项A“加在无风险的贴现率上，以便在决策中把风险考虑进去”是正确的答案。选项B和D都是错误的，因为它们都与风险补偿率的定义不符。选项C“B和C都对”也是不准确的，因为风险补偿率通常是在无风险的贴现率上加上一个额外的补偿率，而不仅仅是用于决策者决策时使用。
# Answer is A
# question 1 is correct!
# {
#     "提示词": "如果其他因素保持不变，下列哪种情况一定会使需求减少",
#     "优化后的提示词": "请选择一个可能会使需求减少的情况？",
#     "选项": ["A. 收入减少，同时互补品的价格下降", "B. 收入增加，同时替代品的价格上涨", "C. 收入减少，同时替代品的价格上涨"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个可能会使需求减少的情况？
# ======
# A 收入减少，同时互补品的价格下降
#  B 收入增加，同时替代品的价格上涨
#  C 收入减少，同时互补品的价格上涨
#  D 收入增加，同时替代品的价格下降
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是C. 收入减少，同时互补品的价格上涨。
#
# 当收入减少时，人们可能更倾向于节约开支，减少一些非必需品的购买，而如果这种非必需品是某个商品的互补品，那么该商品的消费量就会减少。同时，如果互补品的价格下降，那么人们可能会选择购买更多的互补品，这可能会进一步增加对主要商品的需求。然而，在这种情况下，主要商品的需求量并不会直接减少。
#
# 而选项A和B的情况是收入增加，这通常会促进消费，增加对互补品和替代品的需求，从而增加主要商品的需求量。选项D的情况是收入增加，同时替代品的价格下降，这可能会导致人们更多地选择替代品而不是主要商品，从而减少对主要商品的需求量。
#
# 所以，只有选项C描述的情况更可能会使需求减少。
# Answer is C
# question 2 is correct!
# {
#     "提示词": "一个行业有很多企业，每个企业销售的产品与其他企业的产品略有差别，这样的市场结构被称为。",
#     "优化后的提示词": "在这样一个市场中，企业之间的产品差异较大，这样的市场结构被称为垄断竞争。",
#     "选项": ["A. 垄断竞争", "B. 完全竞争", "C. 寡头", "D. 垄断"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 在这样一个市场中，企业之间的产品差异较大，这样的市场结构被称为垄断竞争。
# ======
# A 垄断竞争
#  B 完全竞争
#  C 寡头
#  D 垄断
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是A，垄断竞争。
#
# 在题目中提到，市场中的企业之间的产品差异较大，这种市场结构被称为垄断竞争。因此，选项A垄断竞争是最符合题意的答案。完全竞争、寡头和垄断这三个选项都不符合题意。所以答案是A。
# Answer is A
# question 3 is correct!
# {
#     "提示词": "垄断竞争企业的竞争方式不包括",
#     "优化后的提示词": "垄断竞争企业的竞争方式通常不包括产品差异化竞争和价格竞争，专利竞争和广告和促销竞争是可能的方式之一。",
#     "选项": ["A. 产品差异化竞争", "B. 价格竞争", "C. 专利竞争", "D. 广告和促销竞争"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 垄断竞争企业的竞争方式通常不包括产品差异化竞争和价格竞争，专利竞争和广告和促销竞争是可能的方式之一。
# ======
# A 产品差异化竞争
#  B 价格竞争
#  C 专利竞争
#  D 广告和促销竞争
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是C。
#
# 垄断竞争企业的竞争方式通常包括价格竞争、广告和促销竞争等，但不会包括产品差异化竞争。专利竞争是垄断竞争企业可能采用的竞争方式之一，因为它可以保护企业的技术优势，并阻止其他企业进入该市场。因此，选项C是正确答案。
# Answer is C
# question 4 is correct!
# {
#     "提示词": "提出消费倾向递减心理规律的经济学家是",
#     "优化后的提示词": "提出消费倾向递减心理规律的经济学家是西斯蒙第。",
#     "选项": ["A. 西斯蒙第"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 提出消费倾向递减心理规律的经济学家是西斯蒙第。
# ======
# A 西斯蒙第
#  B 配第
#  C 魁奈
#  D 凯恩斯
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是A
#
# 西斯蒙第提出了消费倾向递减心理规律。他认为，随着收入的增加，消费也会按一定比率增加，但消费增加的比例会低于收入增加的比例，即所谓的边际消费倾向递减。因此，他成为消费理论的重要先驱之一。所以，答案是A西斯蒙第。
# Answer is D
# {
#     "提示词": "需求的收入弹性是指",
#     "优化后的提示词": "请选择一个关于需求的收入弹性的描述？您可以从反应程度、相容性、相关程度中选择一个最符合您理解的定义。",
#     "选项": ["A. 收入对需求变化的反应程度", "B. 需求对收入变化的反应程度", "C. 需求和收入的相容性", "D. 需求和收入的相关程度"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个关于需求的收入弹性的描述？您可以从反应程度、相容性、相关程度中选择一个最符合您理解的定义。
# ======
# A 收入对需求变化的反应程度
#  B 需求对收入变化的反应程度
#  C 需求和收入的相容性
#  D 需求和收入的相关程度
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是B：需求对收入变化的反应程度。
#
# 因为题目中提到的是关于需求的收入弹性的描述，而收入弹性通常是指需求对收入变化的反应程度，即收入每变化一个单位，需求会相应地变化多少。因此，选项B是最符合题目要求的答案。选项A和D描述的是收入对需求变化的反应程度，而选项C描述的是需求和收入的相容性，与题目要求不符。
# Answer is B
# question 6 is correct!
# {
#     "提示词": "企业应该",
#     "优化后的提示词": "请根据投资方案未来全部净现金效益量的现值与期初投资的大小关系，选择一个合适的选项。",
#     "选项": ["A. 还需要再研究", "B. 接受该方案"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请根据投资方案未来全部净现金效益量的现值与期初投资的大小关系，选择一个合适的选项。
# ======
# A 还需要再研究
#  B 接受该方案
#  C 无法确定
#  D 拒绝该方案
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是B。
#
# 解释：
#
# * 未来全部净现金效益量的现值与期初投资的大小关系是评估投资方案的重要指标。如果未来全部净现金效益量的现值大于期初投资，说明该方案在未来会产生更多的现金流入，因此应该接受该方案。
# * 从问题描述中，该投资方案未来全部净现金效益量的现值与期初投资的大小关系无法确定，因此选项C不合适。
# * 拒绝该方案意味着对该方案的评价为负面，但问题中并未给出拒绝该方案的理由，因此选项D也不合适。
#
# 综合考虑，唯一合适的答案是B，接受该方案。
# Answer is B
# question 7 is correct!
# {
#     "提示词": "在完全竞争市场上，一个企业的需求曲线是",
#     "优化后的提示词": "请选择一个完全竞争市场上企业的需求曲线？您可以从与横轴平行的线、向右下方倾斜的线、与横轴垂直的线、与纵轴平行的线中挑选一个最符合您预期的选项。",
#     "选项": ["A. 与横轴平行的线", "B. 向右下方倾斜的线", "C. 与横轴垂直的线", "D. 与纵轴平行的线"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个完全竞争市场上企业的需求曲线？您可以从与横轴平行的线、向右下方倾斜的线、与横轴垂直的线、与纵轴平行的线中挑选一个最符合您预期的选项。
# ======
# A 与横轴平行的线
#  B 向右下方倾斜的线
#  C 与横轴垂直的线
#  D 与纵轴平行的线
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：在完全竞争市场上，企业所面临的需求曲线是**向右下方倾斜的线**。这是因为完全竞争市场上的消费者有无限的购买力，所以可以按照自己的需求量来购买产品，这就使得市场需求曲线向下倾斜。因此，选项B“向右下方倾斜的线”是正确的答案。
# Answer is A
# Error: didn't find answer for this question
# {
#     "提示词": "最常用的三种投资方案评价方法是什么？",
#     "优化后的提示词": "请选择一个最常用的投资方案评价方法？您可以从返本期法、净现值法、成本法中挑选一个最符合您需求的选项。",
#     "选项": ["A. 返本期法、成本法、内部回报率法", "B. 返本期法、净现值法、内部回报率法"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个最常用的投资方案评价方法？您可以从返本期法、净现值法、成本法中挑选一个最符合您需求的选项。
# ======
# A 返本期法、成本法、内部回报率法
#  B 返本期法、净现值法、内部回报率法
#  C 返本期法、净现值法、成本法
#  D 成本法、净现值法、内部回报率法
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是B
#
# 最常用的投资方案评价方法通常包括返本期法、净现值法、成本法等。其中，返本期法主要考虑投资回收期，而净现值法主要考虑投资项目的未来现金流量净现值，成本法则主要考虑投资项目的成本回收。在这些方法中，B选项“返本期法、净现值法、内部回报率法”涵盖了多种投资方案评价方法，并且考虑了投资项目的回收期、未来现金流量净现值和成本回收等多个方面，因此是最常用的投资方案评价方法之一。
# Answer is B
# question 9 is correct!
# {
#     "提示词": "请选择一个投资方案，并考虑其净现金效益量。",
#     "优化后的提示词": "两个投资方案头三年的现金效益量分别为：甲方案l00元、100元和100元，乙方案80元、100元和120元。您需要作贴现计算来确定哪个方案现值大。",
#     "选项": ["C. 两个方案的现值相等"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 两个投资方案头三年的现金效益量分别为：甲方案l00元、100元和100元，乙方案80元、100元和120元。您需要作贴现计算来确定哪个方案现值大。
# ======
# A 乙方案现值大
#  B 甲方案现值大
#  C 两个方案的现值相等
#  D 必须作贴现计算，才能确定哪个方案现值大
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是D
#
# 甲方案头三年的现金效益量分别为：l00元、100元和100元，乙方案头三年的现金效益量分别为：80元、100元和120元。为了确定哪个方案现值大，我们需要对这两个方案的现金效益量进行贴现计算。
#
# 贴现是指将未来的现金流量转换为现在的价值，通常使用一定的利率或贴现率进行折现。我们需要根据这两个方案的现金效益量，选择适当的贴现率，并使用贴现公式来计算它们的现值。
#
# 只有通过贴现计算，才能确定哪个方案的现值大。所以，答案是D，必须作贴现计算，才能确定哪个方案现值大。
# Answer is D
# question 10 is correct!
# {
#     "提示词": "以下现象属于市场失灵的是",
#     "优化后的提示词": "请选择一个属于市场失灵的现象？您可以从收入不平等、市场控制、自然垄断和以上全是中挑选一个最符合您认知的选项。",
#     "选项": ["A. 收入不平等", "B. C. 市场控制", "D. 自然垄断"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个属于市场失灵的现象？您可以从收入不平等、市场控制、自然垄断和以上全是中挑选一个最符合您认知的选项。
# ======
# A 收入不平等
#  B 以上全是
#  C 市场控制
#  D 自然垄断
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是B。市场失灵的现象包括收入不平等、市场控制、自然垄断和以上全是。在这四个选项中，除了自然垄断之外，其他选项都可能引起市场失灵。收入不平等通常是由于市场上的信息不对称、外部效应等因素导致的，而市场控制则可能由于垄断、寡头等市场势力导致市场失灵。因此，其他三个选项都可能引起市场失灵，而B选项包括了所有这些现象，因此是最符合题意的答案。
# Answer is B
# question 11 is correct!
# {
#     "提示词": "当长期均衡时，完全竞争企业总是",
#     "优化后的提示词": "在长期均衡时，完全竞争企业会处于经济利润为零的状态。",
#     "选项": ["D. 经济利润为零"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 在长期均衡时，完全竞争企业会处于经济利润为零的状态。
# ======
# A 经济利润大于零
#  B 正常利润为零
#  C 经济利润小于零
#  D 经济利润为零
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是D。
#
# 在长期均衡时，完全竞争企业会处于经济利润为零的状态。这个说法表明，企业在长期内需要获得正常利润，但不会获得超额利润，即经济利润为零。因此，选项D，“经济利润为零”，是符合这个说法的。而选项A（经济利润大于零）、C（经济利润小于零）都与长期均衡时企业经济利润为零的说法相悖。正常利润为零的说法在原文中并未提及，因此选项B不正确。
# Answer is D
# question 12 is correct!
# {
#     "提示词": "有风险条件下的决策，其决策条件是？",
#     "优化后的提示词": "请选择一个有风险条件下的决策条件？您可以选择决策的可能结果有多个，但不知道每种结果发生的概率。",
#     "选项": ["A. 决策的可能结果有多个，但不知道每种结果发生的概率"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个有风险条件下的决策条件？您可以选择决策的可能结果有多个，但不知道每种结果发生的概率。
# ======
# A 决策的可能结果有多个，但不知道每种结果发生的概率
#  B 决策的可能结果有多个，且每种结果的发生概率为已知
#  C 决策的可能结果有多个
#  D 决策的可能结果只有一个
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是A。
#
# 在有风险条件下的决策条件中，如果决策的可能结果有多个，但不知道每种结果发生的概率，那么这种情况下，决策者就需要考虑各种可能的结果，并做出最佳的决策。这种情况下，决策者需要综合考虑各种因素，包括风险、收益、机会成本等，以做出最优决策。因此，答案A“决策的可能结果有多个，但不知道每种结果发生的概率”是符合这个条件的。
# Answer is B
# {
#     "提示词": "以下可用于衡量一个国家金融发展水平的指标是？",
#     "优化后的提示词": "请选择一个可用于衡量一个国家金融发展水平的指标？您可以从净金融资产、国民生产总值、金融比率、流动性金融资产中挑选一个最符合您需求的选项。",
#     "选项": ["A. 净金融资产", "B. 国民生产总值", "C. 金融比率", "D. 流动性金融资产"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个可用于衡量一个国家金融发展水平的指标？您可以从净金融资产、国民生产总值、金融比率、流动性金融资产中挑选一个最符合您需求的选项。
# ======
# A 净金融资产
#  B 国民生产总值
#  C 金融比率
#  D 流动性金融资产
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：考虑到金融发展水平的全面性和综合性，我选择A. 净金融资产作为答案。净金融资产是一个国家或地区所有常住单位持有的资产净值，包括金融资产减金融负债。它反映了金融体系的规模和效率，以及一个国家或地区的金融发展水平。同时，净金融资产还包括了诸如股票、债券、保险、基金等各类金融资产，能够全面反映一个国家或地区的金融市场发展状况。因此，综合考虑，我认为净金融资产是最适合衡量一个国家金融发展水平的指标。
# Answer is C
# Error: didn't find answer for this question
# {
#     "提示词": "下列治理通货膨胀的宏观经济政策中，属于紧缩性货币政策的是",
#     "优化后的提示词": "请选择一个属于紧缩性货币政策的经济政策？您可以从上述选项中选择最符合的一项。",
#     "选项": ["B.中央银行在公开市场上出售政府债券", "C.控制集团购买力", "D.政府确定工资—物价指导线"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 请选择一个属于紧缩性货币政策的经济政策？您可以从上述选项中选择最符合的一项。
# ======
# A 政府削减财政支出
#  B 中央银行在公开市场上出售政府债券
#  C 控制集团购买力
#  D 政府确定工资—物价指导线
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：中央银行在公开市场上出售政府债券属于紧缩性货币政策。
#
# 当中央银行在公开市场上出售政府债券时，它通过减少货币供应量来抑制通货膨胀。这会导致市场利率上升，进而减少投资和消费，从而降低总需求。这种紧缩性货币政策有助于控制通货膨胀，保持经济的稳定增长。
#
# 而其他选项中，政府削减财政支出、控制集团购买力和政府确定工资—物价指导线虽然可能对经济产生影响，但它们不是典型的紧缩性货币政策。
#
# 因此，答案是B：中央银行在公开市场上出售政府债券。
# Answer is B
# question 15 is correct!
# {
#     "提示词": "实施“次级进口替代”战略的基础是什么？",
#     "优化后的提示词": "实施“次级进口替代”战略的基础是先进的科学技术。",
#     "选项": ["C. 先进的科学技术"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 实施“次级进口替代”战略的基础是先进的科学技术。
# ======
# A 更多的自然资源
#  B 更多的劳动力
#  C 先进的科学技术
#  D 发达的金融市场
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
# 文言一心的回答是：答案是C。
#
# 在题目给出的信息中，“实施‘次级进口替代’战略的基础是先进的科学技术”，这表明实施这个战略需要依靠先进的科学技术。而四个选项中，只有C选项是“先进的科学技术”，所以C是正确答案。而A、B、D选项虽然也可能对实施战略有所帮助，但不是基础和关键因素。
# Answer is A
# {
#     "提示词": "假定名义货币供给量不变，价格总水平上升将导致一条向右上方倾斜的LM曲线上的一点。",
#     "优化后的提示词": "当价格总水平上升时，货币需求量也会相应增加，这将导致LM曲线向右上方移动。",
#     "选项": ["A. 沿原LM曲线向下方移动", "B. 沿原LM曲线向上方移动", "C. 向左移动到另一条LM曲线上", "D. 向右移动到另一条LM曲线上"]
# }
# new prompt is
# 这个题目是单选题
#
# #回答格式#
# 答案是【你的答案】来标注你的答案。
#
# #答案选项#
# A
#
# B
#
# C
#
# D
#
# #样例#
# 答案是A
#
# ======
# 当价格总水平上升时，货币需求量也会相应增加，这将导致LM曲线向右上方移动。
# ======
# A 沿原LM曲线向下方移动
#  B 沿原LM曲线向上方移动
#  C 向左移动到另一条LM曲线上
#  D 向右移动到另一条LM曲线上
#
# ######
# 请注意， 你的回答应该清晰、准确、简洁，并提供足够的细节来支持你的答案。让我们一步一步来思考。
